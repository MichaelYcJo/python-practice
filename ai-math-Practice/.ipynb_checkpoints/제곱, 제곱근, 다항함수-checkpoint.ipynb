# %%
# 거듭제곱을 코드로 구현해보자

# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# 거듭제곱은 ** 으로 나타낸다.
def my_func(x):
    a = 3
    return x**3

x = np.linspace(0, 2)
y = my_func(x)

plt.plot(x, y)
plt.xlabel("x", size=14)
plt.ylabel("y", size=14)
plt.grid()
plt.show()

# %%
#제곱근

# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# sqrt()는 양의 제곱근을 나타내는 수로, x**(1/2) 와 같은 말이다. 
def my_function(x):
    return np.sqrt(x)

x = np.linspace(0, 9)
y = my_func(x)
print(y)

plt.plot(x, y)
plt.xlabel("x", size=14, color='white')
plt.ylabel("y", size=14, color='white')
plt.grid()
plt.show()
# Out:
# [0.00000000e+00 6.19639776e-03 4.95711821e-02 1.67302740e-01
#  3.96569457e-01 7.74549720e-01 1.33842192e+00 2.12536443e+00
#  3.17255565e+00 4.51717397e+00 6.19639776e+00 8.24740542e+00
#  1.07073753e+01 1.36134859e+01 1.70029155e+01 2.09128424e+01
#  2.53804452e+01 3.04429022e+01 3.61373917e+01 4.25010922e+01
#  4.95711821e+01 5.73848397e+01 6.59792433e+01 7.53915715e+01
#  8.56590026e+01 9.68187150e+01 1.08907887e+02 1.21963697e+02
#  1.36023324e+02 1.51123945e+02 1.67302740e+02 1.84596886e+02
#  2.03043562e+02 2.22679946e+02 2.43543218e+02 2.65670554e+02
#  2.89099134e+02 3.13866136e+02 3.40008738e+02 3.67564119e+02
#  3.96569457e+02 4.27061930e+02 4.59078717e+02 4.92656997e+02
#  5.27833947e+02 5.64646746e+02 6.03132572e+02 6.43328605e+02
#  6.85272021e+02 7.29000000e+02]
